# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima_model import ARIMA
import datetime
from sklearn.metrics import mean_squared_error
from pandas.plotting import autocorrelation_plot

for a in range(19,20):
    series = pd.read_csv('cluster_'+str(a)+'_Arima.csv', usecols=['Tahun','count'],header=0, parse_dates=[0], index_col=0, squeeze=True)
    autocorrelation_plot(series)
    # plt.show()
    plt.savefig("correlation "+str(a)+".png")

    model = ARIMA(series, order=(1,0,0))
    model_fit = model.fit(disp=0)
    print(model_fit.summary())
    # plot residual errors
    residuals = pd.DataFrame(model_fit.resid)
    residuals.plot()
    # plt.show()
    plt.savefig("residual "+str(a)+".png")
    residuals.plot(kind='kde')
    # plt.show()
    plt.savefig("KDE "+str(a)+".png")
    print(residuals.describe())

    X = series.values
    size = int(len(X) * 0.66)
    train, test = X[0:size], X[size:len(X)]
    history = [x for x in train]
    predictions = list()
    for t in range(len(test)):
        model = ARIMA(history, order=(1,0,0))
        model_fit = model.fit(disp=0)
        output = model_fit.forecast()
        yhat = output[0]
        predictions.append(yhat)
        obs = test[t]
        history.append(obs)
        print('predicted=%f, expected=%f' % (yhat, obs))
    error = mean_squared_error(test, predictions)
    print('Test MSE: %.3f' % error)
    # plot
    plt.title("ARIMA Cluster "+str(a))
    plt.plot(test)
    plt.plot(predictions, color='red')
    plt.savefig("Plot prediction "+str(a)+".png")
    # plt.show()
# Out:
# C:\Users\Ahmad Shohibus S\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\base\tsa_model.py:215: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\Ahmad Shohibus S\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\base\tsa_model.py:215: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                D.count   No. Observations:                   11
# Model:                 ARIMA(2, 1, 0)   Log Likelihood                 -55.469
# Method:                       css-mle   S.D. of innovations             36.745
# Date:                Thu, 26 Sep 2019   AIC                            118.938
# Time:                        22:26:28   BIC                            120.530
# Sample:                             1   HQIC                           117.935
#
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            -0.4391      6.185     -0.071      0.945     -12.561      11.683
# ar.L1.D.count    -0.6176      0.278     -2.223      0.057      -1.162      -0.073
# ar.L2.D.count    -0.2866      0.264     -1.085      0.309      -0.804       0.231
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -1.0775           -1.5258j            1.8679           -0.3479
# AR.2           -1.0775           +1.5258j            1.8679            0.3479
# -----------------------------------------------------------------------------
#                 0
# count   11.000000
# mean     1.435930
# std     38.679263
# min    -38.592311
# 25%    -21.056101
# 50%     -4.994529
# 75%     11.690188
# max    103.498124
# C:\Users\Ahmad Shohibus S\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\tsatools.py:649: RuntimeWarning: invalid value encountered in double_scalars
#   (1-a**2)
# C:\Users\Ahmad Shohibus S\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\tsatools.py:651: RuntimeWarning: divide by zero encountered in arctanh
#   invarcoefs = 2*np.arctanh(params)
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-23-225d88b1ea9c> in <module>
#      33     for t in range(len(test)):
#      34         model = ARIMA(history, order=(2,1,0))
# ---> 35         model_fit = model.fit(disp=0)
#      36         output = model_fit.forecast()
#      37         yhat = output[0]
#
# ~\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\arima_model.py in fit(self, start_params, trend, method, transparams, solver, maxiter, full_output, disp, callback, start_ar_lags, **kwargs)
#    1147                                            method, transparams, solver,
#    1148                                            maxiter, full_output, disp,
# -> 1149                                            callback, start_ar_lags, **kwargs)
#    1150         normalized_cov_params = None  # TODO: fix this?
#    1151         arima_fit = ARIMAResults(self, mlefit._results.params,
#
# ~\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\arima_model.py in fit(self, start_params, trend, method, transparams, solver, maxiter, full_output, disp, callback, start_ar_lags, **kwargs)
#     949                                        maxiter=maxiter,
#     950                                        full_output=full_output, disp=disp,
# --> 951                                        callback=callback, **kwargs)
#     952         params = mlefit.params
#     953
#
# ~\AppData\Roaming\Python\Python37\site-packages\statsmodels\base\model.py in fit(self, start_params, method, maxiter, full_output, disp, fargs, callback, retall, skip_hessian, **kwargs)
#     468                                                        callback=callback,
#     469                                                        retall=retall,
# --> 470                                                        full_output=full_output)
#     471
#     472         # NOTE: this is for fit_regularized and should be generalized
#
# ~\AppData\Roaming\Python\Python37\site-packages\statsmodels\base\optimizer.py in _fit(self, objective, gradient, start_params, fargs, kwargs, hessian, method, maxiter, full_output, disp, callback, retall)
#     217                             disp=disp, maxiter=maxiter, callback=callback,
#     218                             retall=retall, full_output=full_output,
# --> 219                             hess=hessian)
#     220
#     221         optim_settings = {'optimizer': method, 'start_params': start_params,
#
# ~\AppData\Roaming\Python\Python37\site-packages\statsmodels\base\optimizer.py in _fit_lbfgs(f, score, start_params, fargs, kwargs, disp, maxiter, callback, retall, full_output, hess)
#     437                                      callback=callback, args=fargs,
#     438                                      bounds=bounds, disp=disp,
# --> 439                                      **extra_kwargs)
#     440
#     441     if full_output:
#
# ~\AppData\Roaming\Python\Python37\site-packages\scipy\optimize\lbfgsb.py in fmin_l_bfgs_b(func, x0, fprime, args, approx_grad, bounds, m, factr, pgtol, epsilon, iprint, maxfun, maxiter, disp, callback, maxls)
#     197
#     198     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
# --> 199                            **opts)
#     200     d = {'grad': res['jac'],
#     201          'task': res['message'],
#
# ~\AppData\Roaming\Python\Python37\site-packages\scipy\optimize\lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, **unknown_options)
#     333             # until the completion of the current minimization iteration.
#     334             # Overwrite f and g:
# --> 335             f, g = func_and_grad(x)
#     336         elif task_str.startswith(b'NEW_X'):
#     337             # new iteration
#
# ~\AppData\Roaming\Python\Python37\site-packages\scipy\optimize\lbfgsb.py in func_and_grad(x)
#     278     if jac is None:
#     279         def func_and_grad(x):
# --> 280             f = fun(x, *args)
#     281             g = _approx_fprime_helper(x, fun, epsilon, args=args, f0=f)
#     282             return f, g
#
# ~\AppData\Roaming\Python\Python37\site-packages\scipy\optimize\optimize.py in function_wrapper(*wrapper_args)
#     298     def function_wrapper(*wrapper_args):
#     299         ncalls[0] += 1
# --> 300         return function(*(wrapper_args + args))
#     301
#     302     return ncalls, function_wrapper
#
# ~\AppData\Roaming\Python\Python37\site-packages\statsmodels\base\model.py in f(params, *args)
#     442
#     443         def f(params, *args):
# --> 444             return -self.loglike(params, *args) / nobs
#     445
#     446         if method == 'newton':
#
# ~\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\arima_model.py in loglike(self, params, set_sigma2)
#     770         method = self.method
#     771         if method in ['mle', 'css-mle']:
# --> 772             return self.loglike_kalman(params, set_sigma2)
#     773         elif method == 'css':
#     774             return self.loglike_css(params, set_sigma2)
#
# ~\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\arima_model.py in loglike_kalman(self, params, set_sigma2)
#     780         Compute exact loglikelihood for ARMA(p,q) model by the Kalman Filter.
#     781         """
# --> 782         return KalmanFilter.loglike(params, self, set_sigma2)
#     783
#     784     def loglike_css(self, params, set_sigma2=True):
#
# ~\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\kalmanf\kalmanfilter.py in loglike(cls, params, arma_model, set_sigma2)
#     219             loglike, sigma2 = kalman_loglike.kalman_loglike_double(
#     220                 y, k, k_ar, k_ma, k_lags, int(nobs),
# --> 221                 Z_mat, R_mat, T_mat)
#     222         elif np.issubdtype(paramsdtype, np.complex128):
#     223             loglike, sigma2 = kalman_loglike.kalman_loglike_complex(
#
# statsmodels\tsa\kalmanf\kalman_loglike.pyx in statsmodels.tsa.kalmanf.kalman_loglike.kalman_loglike_double()
#
# statsmodels\tsa\kalmanf\kalman_loglike.pyx in statsmodels.tsa.kalmanf.kalman_loglike.kalman_filter_double()
#
# ~\AppData\Roaming\Python\Python37\site-packages\numpy\linalg\linalg.py in pinv(a, rcond)
#    1936         return wrap(res)
#    1937     a = a.conjugate()
# -> 1938     u, s, vt = svd(a, full_matrices=False)
#    1939
#    1940     # discard small singular values
#
# ~\AppData\Roaming\Python\Python37\site-packages\numpy\linalg\linalg.py in svd(a, full_matrices, compute_uv)
#    1610
#    1611         signature = 'D->DdD' if isComplexType(t) else 'd->ddd'
# -> 1612         u, s, vh = gufunc(a, signature=signature, extobj=extobj)
#    1613         u = u.astype(result_t, copy=False)
#    1614         s = s.astype(_realType(result_t), copy=False)
#
# ~\AppData\Roaming\Python\Python37\site-packages\numpy\linalg\linalg.py in _raise_linalgerror_svd_nonconvergence(err, flag)
#     104
#     105 def _raise_linalgerror_svd_nonconvergence(err, flag):
# --> 106     raise LinAlgError("SVD did not converge")
#     107
#     108 def _raise_linalgerror_lstsq(err, flag):
#
# LinAlgError: SVD did not converge

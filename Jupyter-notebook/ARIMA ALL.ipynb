# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima_model import ARIMA
import datetime
from pandas.plotting import autocorrelation_plot

# %%
for a in range(20):
    datacluster = pd.read_csv("cluster_"+str(a)+"_Arima.csv")
    datacluster.Tahun = pd.to_datetime(datacluster.Tahun, format="%Y%m")
    x = datacluster['Tahun']
    y = datacluster['count']
    plt.figure(figsize=(10,10))
    plt.title(str(a))
    plt.plot(x,y)

# %%
for a in range(20):
    series = pd.read_csv("cluster_"+str(a)+"_Arima.csv", header=0, parse_dates=[0],index_col=0, squeeze=True)
    autocorrelation_plot(series)
    plt.show()
    model = ARIMA(series,order = (3,1,1))
    model_fit = model.fit(disp=0)
    print("=====model %d=====" % a)
    print(model_fit.summary())
    residuals = pd.DataFrame(model_fit.resid)
    plt.title("residuals "+str(a))
    residuals.plot()
    plt.show()
    plt.title("KDE residuals "+str(a))
    plt.show()
    print("============================")
# Out:
# C:\Users\Ahmad Shohibus S\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\base\tsa_model.py:215: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\Ahmad Shohibus S\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\base\tsa_model.py:215: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# =====model 0=====
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                D.count   No. Observations:                   37
# Model:                 ARIMA(3, 1, 1)   Log Likelihood                -185.625
# Method:                       css-mle   S.D. of innovations             34.870
# Date:                Thu, 26 Sep 2019   AIC                            383.250
# Time:                        20:30:49   BIC                            392.915
# Sample:                             1   HQIC                           386.657
#
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            -0.5405      0.673     -0.803      0.428      -1.859       0.778
# ar.L1.D.count     0.3185      0.180      1.768      0.087      -0.035       0.671
# ar.L2.D.count    -0.2646      0.189     -1.401      0.171      -0.635       0.106
# ar.L3.D.count     0.1471      0.330      0.445      0.659      -0.500       0.795
# ma.L1.D.count    -1.0000      0.121     -8.232      0.000      -1.238      -0.762
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -0.2058           -1.7415j            1.7536           -0.2687
# AR.2           -0.2058           +1.7415j            1.7536            0.2687
# AR.3            2.2107           -0.0000j            2.2107           -0.0000
# MA.1            1.0000           +0.0000j            1.0000            0.0000
# -----------------------------------------------------------------------------
# ============================
# C:\Users\Ahmad Shohibus S\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\base\tsa_model.py:215: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\Ahmad Shohibus S\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\base\tsa_model.py:215: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# =====model 1=====
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                D.count   No. Observations:                   66
# Model:                 ARIMA(3, 1, 1)   Log Likelihood                -352.099
# Method:                       css-mle   S.D. of innovations             49.960
# Date:                Thu, 26 Sep 2019   AIC                            716.199
# Time:                        20:30:50   BIC                            729.337
# Sample:                             1   HQIC                           721.390
#
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             1.9287      3.491      0.553      0.583      -4.913       8.770
# ar.L1.D.count    -0.9079      0.612     -1.482      0.143      -2.108       0.292
# ar.L2.D.count    -0.2627      0.496     -0.529      0.598      -1.235       0.710
# ar.L3.D.count     0.0669      0.197      0.339      0.735      -0.319       0.453
# ma.L1.D.count     0.1768      0.600      0.294      0.769      -1.000       1.354
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -1.2410           -0.8903j            1.5273           -0.4010
# AR.2           -1.2410           +0.8903j            1.5273            0.4010
# AR.3            6.4094           -0.0000j            6.4094           -0.0000
# MA.1           -5.6562           +0.0000j            5.6562            0.5000
# -----------------------------------------------------------------------------
# ============================
# C:\Users\Ahmad Shohibus S\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\base\tsa_model.py:215: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\Ahmad Shohibus S\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\base\tsa_model.py:215: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# =====model 2=====
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                D.count   No. Observations:                   66
# Model:                 ARIMA(3, 1, 1)   Log Likelihood                -439.832
# Method:                       css-mle   S.D. of innovations            188.812
# Date:                Thu, 26 Sep 2019   AIC                            891.665
# Time:                        20:30:51   BIC                            904.803
# Sample:                             1   HQIC                           896.856
#
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             6.7041     16.289      0.412      0.682     -25.222      38.630
# ar.L1.D.count    -0.8663      0.386     -2.243      0.029      -1.623      -0.109
# ar.L2.D.count    -0.0658      0.300     -0.219      0.827      -0.654       0.522
# ar.L3.D.count     0.1593      0.129      1.238      0.221      -0.093       0.412
# ma.L1.D.count     0.2368      0.376      0.631      0.531      -0.499       0.973
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -1.2750           -0.7020j            1.4555           -0.4199
# AR.2           -1.2750           +0.7020j            1.4555            0.4199
# AR.3            2.9635           -0.0000j            2.9635           -0.0000
# MA.1           -4.2228           +0.0000j            4.2228            0.5000
# -----------------------------------------------------------------------------
# ============================
# C:\Users\Ahmad Shohibus S\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\base\tsa_model.py:215: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\Ahmad Shohibus S\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\base\tsa_model.py:215: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# =====model 3=====
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                D.count   No. Observations:                   24
# Model:                 ARIMA(3, 1, 1)   Log Likelihood                 -92.829
# Method:                       css-mle   S.D. of innovations             10.795
# Date:                Thu, 26 Sep 2019   AIC                            197.659
# Time:                        20:30:51   BIC                            204.727
# Sample:                             1   HQIC                           199.534
#
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            -0.7739      0.307     -2.523      0.021      -1.375      -0.173
# ar.L1.D.count     0.1430      0.235      0.608      0.551      -0.318       0.604
# ar.L2.D.count    -0.1277      0.341     -0.374      0.712      -0.796       0.541
# ar.L3.D.count    -0.0618      0.320     -0.193      0.849      -0.689       0.566
# ma.L1.D.count    -1.0000      0.138     -7.267      0.000      -1.270      -0.730
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            0.8657           -1.8738j            2.0641           -0.1811
# AR.2            0.8657           +1.8738j            2.0641            0.1811
# AR.3           -3.7971           -0.0000j            3.7971           -0.5000
# MA.1            1.0000           +0.0000j            1.0000            0.0000
# -----------------------------------------------------------------------------
# ============================
# C:\Users\Ahmad Shohibus S\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\base\tsa_model.py:215: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\Ahmad Shohibus S\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\base\tsa_model.py:215: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# =====model 4=====
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                D.count   No. Observations:                   34
# Model:                 ARIMA(3, 1, 1)   Log Likelihood                -173.353
# Method:                       css-mle   S.D. of innovations             38.108
# Date:                Thu, 26 Sep 2019   AIC                            358.705
# Time:                        20:30:52   BIC                            367.863
# Sample:                             1   HQIC                           361.828
#
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            -1.7741      1.058     -1.677      0.104      -3.847       0.299
# ar.L1.D.count     0.1576      0.197      0.799      0.431      -0.229       0.544
# ar.L2.D.count     0.1187      0.185      0.643      0.525      -0.243       0.480
# ar.L3.D.count     0.1569      0.304      0.517      0.609      -0.438       0.752
# ma.L1.D.count    -1.0000      0.099    -10.089      0.000      -1.194      -0.806
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.4787           -0.0000j            1.4787           -0.0000
# AR.2           -1.1174           -1.7494j            2.0758           -0.3405
# AR.3           -1.1174           +1.7494j            2.0758            0.3405
# MA.1            1.0000           +0.0000j            1.0000            0.0000
# -----------------------------------------------------------------------------
# ============================
# C:\Users\Ahmad Shohibus S\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\base\tsa_model.py:215: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\Ahmad Shohibus S\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\base\tsa_model.py:215: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# =====model 5=====
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                D.count   No. Observations:                   66
# Model:                 ARIMA(3, 1, 1)   Log Likelihood                -399.342
# Method:                       css-mle   S.D. of innovations            100.476
# Date:                Thu, 26 Sep 2019   AIC                            810.683
# Time:                        20:30:53   BIC                            823.821
# Sample:                             1   HQIC                           815.875
#
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            -4.4955      4.095     -1.098      0.277     -12.521       3.530
# ar.L1.D.count    -0.8729      0.306     -2.851      0.006      -1.473      -0.273
# ar.L2.D.count    -0.9753      0.185     -5.279      0.000      -1.337      -0.613
# ar.L3.D.count    -0.6464      0.236     -2.743      0.008      -1.108      -0.185
# ma.L1.D.count     0.1314      0.354      0.371      0.712      -0.563       0.825
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -0.0770           -1.0658j            1.0685           -0.2615
# AR.2           -0.0770           +1.0658j            1.0685            0.2615
# AR.3           -1.3549           -0.0000j            1.3549           -0.5000
# MA.1           -7.6092           +0.0000j            7.6092            0.5000
# -----------------------------------------------------------------------------
# ============================
# C:\Users\Ahmad Shohibus S\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\base\tsa_model.py:215: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\Ahmad Shohibus S\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\base\tsa_model.py:215: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# =====model 6=====
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                D.count   No. Observations:                   18
# Model:                 ARIMA(3, 1, 1)   Log Likelihood                 -58.416
# Method:                       css-mle   S.D. of innovations              5.664
# Date:                Thu, 26 Sep 2019   AIC                            128.833
# Time:                        20:30:53   BIC                            134.175
# Sample:                             1   HQIC                           129.569
#
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            -0.2034      0.238     -0.854      0.409      -0.670       0.263
# ar.L1.D.count     0.2491      0.245      1.016      0.328      -0.231       0.730
# ar.L2.D.count    -0.1884      0.228     -0.825      0.424      -0.636       0.259
# ar.L3.D.count    -0.1620      0.241     -0.673      0.513      -0.634       0.310
# ma.L1.D.count    -0.9999      0.166     -6.025      0.000      -1.325      -0.675
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            0.7362           -1.3418j            1.5305           -0.1701
# AR.2            0.7362           +1.3418j            1.5305            0.1701
# AR.3           -2.6353           -0.0000j            2.6353           -0.5000
# MA.1            1.0001           +0.0000j            1.0001            0.0000
# -----------------------------------------------------------------------------
# ============================
# C:\Users\Ahmad Shohibus S\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\base\tsa_model.py:215: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\Ahmad Shohibus S\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\base\tsa_model.py:215: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# =====model 7=====
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                D.count   No. Observations:                   53
# Model:                 ARIMA(3, 1, 1)   Log Likelihood                -371.472
# Method:                       css-mle   S.D. of innovations            258.599
# Date:                Thu, 26 Sep 2019   AIC                            754.943
# Time:                        20:30:54   BIC                            766.765
# Sample:                             1   HQIC                           759.489
#
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            -5.2923      3.389     -1.562      0.125     -11.935       1.350
# ar.L1.D.count    -0.0091      0.141     -0.064      0.949      -0.286       0.268
# ar.L2.D.count    -0.0274      0.141     -0.194      0.847      -0.304       0.250
# ar.L3.D.count     0.4114      0.248      1.661      0.103      -0.074       0.897
# ma.L1.D.count    -1.0000      0.076    -13.172      0.000      -1.149      -0.851
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -0.6531           -1.1594j            1.3307           -0.3316
# AR.2           -0.6531           +1.1594j            1.3307            0.3316
# AR.3            1.3726           -0.0000j            1.3726           -0.0000
# MA.1            1.0000           +0.0000j            1.0000            0.0000
# -----------------------------------------------------------------------------
# ============================
# C:\Users\Ahmad Shohibus S\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\base\tsa_model.py:215: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\Ahmad Shohibus S\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\base\tsa_model.py:215: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# =====model 8=====
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                D.count   No. Observations:                   66
# Model:                 ARIMA(3, 1, 1)   Log Likelihood                -401.409
# Method:                       css-mle   S.D. of innovations            104.848
# Date:                Thu, 26 Sep 2019   AIC                            814.819
# Time:                        20:30:55   BIC                            827.956
# Sample:                             1   HQIC                           820.010
#
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.1564      2.178      0.072      0.943      -4.112       4.425
# ar.L1.D.count     0.3637      0.225      1.616      0.111      -0.077       0.805
# ar.L2.D.count    -0.0541      0.185     -0.293      0.771      -0.416       0.308
# ar.L3.D.count    -0.0912      0.223     -0.410      0.684      -0.528       0.345
# ma.L1.D.count    -0.9053      0.223     -4.065      0.000      -1.342      -0.469
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.2350           -1.4330j            1.8917           -0.1368
# AR.2            1.2350           +1.4330j            1.8917            0.1368
# AR.3           -3.0632           -0.0000j            3.0632           -0.5000
# MA.1            1.1046           +0.0000j            1.1046            0.0000
# -----------------------------------------------------------------------------
# ============================
# C:\Users\Ahmad Shohibus S\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\base\tsa_model.py:215: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-a1f7b94fbb1e> in <module>
#       3     autocorrelation_plot(series)
#       4     plt.show()
# ----> 5     model = ARIMA(series,order = (3,1,1))
#       6     model_fit = model.fit(disp=0)
#       7     print("=====model %d=====" % a)
#
# ~\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\arima_model.py in __new__(cls, endog, order, exog, dates, freq, missing)
#     986         else:
#     987             mod = super(ARIMA, cls).__new__(cls)
# --> 988             mod.__init__(endog, order, exog, dates, freq, missing)
#     989             return mod
#     990
#
# ~\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\arima_model.py in __init__(self, endog, order, exog, dates, freq, missing)
#    1010         self.endog = np.diff(self.endog, n=d)
#    1011         #NOTE: will check in ARMA but check again since differenced now
# -> 1012         _check_estimable(len(self.endog), p+q)
#    1013         if exog is not None:
#    1014             self.exog = self.exog[d:]
#
# ~\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\arima_model.py in _check_estimable(nobs, n_params)
#     408 def _check_estimable(nobs, n_params):
#     409     if nobs <= n_params:
# --> 410         raise ValueError("Insufficient degrees of freedom to estimate")
#     411
#     412
#
# ValueError: Insufficient degrees of freedom to estimate
